# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline , make_pipeline
from sklearn.feature_selection import SelectKBest , chi2
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("student_exam_performance.csv")
df.head()
# Out:
#   student_id  gender  study_hours  class_participation  attendance_rate  \
# 0      S1000    Male          0.4                    9             95.4
# 1      S1001    Male          8.0                    9             68.8
# 2      S1002  Female          6.7                   10             97.1
# 3      S1003    Male          7.8                    5             59.9
# 4      S1004    Male          7.4                    7             79.6
#
#    previous_scores parental_education internet_access passed
# 0             64.0           Bachelor              No    Yes
# 1             85.6        High School              No    Yes
# 2             42.2        High School             Yes    Yes
# 3             45.3        High School              No    Yes
# 4             55.1             Master              No    Yes

# %%
df.drop(columns=['student_id'],inplace=True)

# %%
df.head()
# Out:
#    gender  study_hours  class_participation  attendance_rate  previous_scores  \
# 0    Male          0.4                    9             95.4             64.0
# 1    Male          8.0                    9             68.8             85.6
# 2  Female          6.7                   10             97.1             42.2
# 3    Male          7.8                    5             59.9             45.3
# 4    Male          7.4                    7             79.6             55.1
#
#   parental_education internet_access passed
# 0           Bachelor              No    Yes
# 1        High School              No    Yes
# 2        High School             Yes    Yes
# 3        High School              No    Yes
# 4             Master              No    Yes

# %%
df.isnull().sum()
# Out:
# gender                 0
# study_hours            0
# class_participation    0
# attendance_rate        0
# previous_scores        0
# parental_education     0
# internet_access        0
# passed                 0
# dtype: int64

# %%
# Train _ test _ split -> 
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['passed']),
                                                 df['passed'],
                                                 test_size=0.2,
                                                 random_state=42)

# %%
X_train.head()
# Out:
#      gender  study_hours  class_participation  attendance_rate  \
# 79   Female          0.9                    3             97.5
# 197    Male          0.0                    4             70.6
# 38   Female          1.0                    6             63.9
# 24   Female          4.6                    3             73.0
# 122  Female          7.4                    3             88.8
#
#      previous_scores parental_education internet_access
# 79              49.1           Bachelor              No
# 197             57.7             Master             Yes
# 38              82.3             Master             Yes
# 24              77.8             Master             Yes
# 122             65.8        High School              No

# %%
X_test.head()
# Out:
#      gender  study_hours  class_participation  attendance_rate  \
# 95     Male          5.1                    3             52.7
# 15     Male          3.6                    8             83.1
# 30   Female          6.8                    7             96.0
# 158    Male          1.4                    4             53.0
# 128    Male          5.9                    5             78.4
#
#      previous_scores parental_education internet_access
# 95              77.4             Master             Yes
# 15              69.9        High School              No
# 30              53.5        High School             Yes
# 158             63.7           Bachelor             Yes
# 128             76.6           Bachelor              No

# %% [markdown]
# # Encode Categorical Variables

# %%
categorical_cols = ['gender', 'internet_access', 'parental_education']
numeric_cols = ['math_score', 'reading_score', 'writing_score', 'class_participation']

# %%
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(transformers=[
    ('num', MinMaxScaler(), numeric_cols),
    ('cat', OneHotEncoder(drop='first'), categorical_cols)
])

# %% [markdown]
# from sklearn
# preprocessor = ColumnTransformer(transformers=[
#     ('num', MinMaxScaler(), numeric_cols),
#     ('cat', OneHotEncoder(drop='first'), categorical_cols)
# ])

# %%
from sklearn.linear_model import LogisticRegression
pipe = Pipeline(steps=[
    ('preprocess', preprocessor),
    ('model', LogisticRegression())
])

# %%
pipe = Pipeline(steps=[
    ('preprocess', preprocessor),
    ('model', LogisticRegression())
])

# %%
pipe.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'math_score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
