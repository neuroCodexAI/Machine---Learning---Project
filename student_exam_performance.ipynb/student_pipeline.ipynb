# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline , make_pipeline
from sklearn.feature_selection import SelectKBest , chi2
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("student_exam_performance.csv")
df.head()
# Out:
#   student_id  gender  study_hours  class_participation  attendance_rate  \
# 0      S1000    Male          0.4                    9             95.4
# 1      S1001    Male          8.0                    9             68.8
# 2      S1002  Female          6.7                   10             97.1
# 3      S1003    Male          7.8                    5             59.9
# 4      S1004    Male          7.4                    7             79.6
#
#    previous_scores parental_education internet_access passed
# 0             64.0           Bachelor              No    Yes
# 1             85.6        High School              No    Yes
# 2             42.2        High School             Yes    Yes
# 3             45.3        High School              No    Yes
# 4             55.1             Master              No    Yes

# %%
df.drop(columns=['student_id'],inplace=True)

# %%
df.head()
# Out:
#    gender  study_hours  class_participation  attendance_rate  previous_scores  \
# 0    Male          0.4                    9             95.4             64.0
# 1    Male          8.0                    9             68.8             85.6
# 2  Female          6.7                   10             97.1             42.2
# 3    Male          7.8                    5             59.9             45.3
# 4    Male          7.4                    7             79.6             55.1
#
#   parental_education internet_access passed
# 0           Bachelor              No    Yes
# 1        High School              No    Yes
# 2        High School             Yes    Yes
# 3        High School              No    Yes
# 4             Master              No    Yes

# %%
df.isnull().sum()
# Out:
# gender                 0
# study_hours            0
# class_participation    0
# attendance_rate        0
# previous_scores        0
# parental_education     0
# internet_access        0
# passed                 0
# dtype: int64

# %% [markdown]
# # Encode Categorical Variables

# %%
ohn = OneHotEncoder()
df_encode = pd.get_dummies(df, columns=['gender', 'parental_education', 'internet_access'], drop_first=True)

df['passed'] = df['passed'].map({'No': 0, 'Yes': 1})

# %%
df_encode.head()
# Out:
#    study_hours  class_participation  attendance_rate  previous_scores passed  \
# 0          0.4                    9             95.4             64.0    Yes
# 1          8.0                    9             68.8             85.6    Yes
# 2          6.7                   10             97.1             42.2    Yes
# 3          7.8                    5             59.9             45.3    Yes
# 4          7.4                    7             79.6             55.1    Yes
#
#    gender_Male  parental_education_High School  parental_education_Master  \
# 0         True                           False                      False
# 1         True                            True                      False
# 2        False                            True                      False
# 3         True                            True                      False
# 4         True                           False                       True
#
#    internet_access_Yes
# 0                False
# 1                False
# 2                 True
# 3                False
# 4                False
